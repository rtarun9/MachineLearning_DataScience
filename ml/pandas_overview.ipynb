# %%
import pandas as pd

# %%
# Dataframe : a table (array of individual entries)
df = pd.DataFrame({'Name' : ['abc', 'def'], 'Age' : [20, 30]})
df
# Out:
#   Name  Age
# 0  abc   20
# 1  def   30

# %%
df = pd.DataFrame({'Name' : ['abc', 'def'], 'Age' : [20, 30]}, index=['idx1', 'idx2'])
df
# Out:
#      Name  Age
# idx1  abc   20
# idx2  def   30

# %%
# Series : sequence of values (a list)
series = pd.Series([1, 2, 3, 4, 5])
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series = pd.Series([100, 200, 300], index=['a', 'b', 'c'], name='A series')
series
# Out:
# a    100
# b    200
# c    300
# Name: A series, dtype: int64

# %%
# Read a CSV file.
df = pd.read_csv('../data_sets/creditcard.csv')
df.shape
# Out:
# (800, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 2  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 3  6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 4  7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211  0.320198  0.044519
# 1 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966 -0.293803  0.279798
# 2 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726 -0.087330 -0.156114
# 3 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207 -0.053502  0.252405
# 4 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805 -1.632653  1.488901
#
# ...

# %%
# Use the first column as index rather than the default index numbers (0...N-1)
df = pd.read_csv('../data_sets/creditcard.csv', index_col=0)
df
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# Time
# 406  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 472  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
# ...        ...       ...       ...       ...       ...       ...       ...
# 287   1.030072 -0.295088 -0.109924  0.071540 -0.318253 -0.912976  0.431930
# 288  -0.598820  0.073254 -0.113786 -2.315189  1.644382  4.389522  3.174203
# 288   1.098584 -1.222491 -0.319125 -1.723385 -0.416168  0.635065 -0.417852
# 288   1.268069  0.285832 -0.147276  1.047742  0.672115  0.656656  0.138315
# 289  -1.782116 -0.326079  2.282092 -0.381814  1.061290  2.666355  0.311426
#
# ...

# %%
# Indexing into a data frame.
#print(df.V4)
print(df['V4'][0])
# Out:
# Time
# 0    1.378155
# 0    0.448154
# Name: V4, dtype: float64

# %%
df = pd.read_csv('../data_sets/age_sex.csv')
print(df.head())
print(df.describe())
print(df.iloc[0])
# Out:
#    SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0    0    0        3944153            3944160          3951330
# 1    0    1        3978070            3978090          3957888
# 2    0    2        4096929            4096939          4090862
# 3    0    3        4119040            4119051          4111920
# 4    0    4        4063170            4063186          4077551
#
#    POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0          3963087          3926540          3931141          3949775
# 1          3966551          3977939          3942872          3949776
# 2          3971565          3980095          3992720          3959664
# 3          4102470          3983157          3992734          4007079
# 4          4122294          4112849          3994449          4005716
#
#    POPESTIMATE2015
# 0          3978038
# 1          3968564
# 2          3966583
# 3          3974061
# 4          4020035
# ...

# %%
# Get first two columns and first two rows of the dataframe.
df.iloc[0:2,0:2]
df.iloc[:,0]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 301    2
# 302    2
# 303    2
# 304    2
# 305    2
# Name: SEX, Length: 306, dtype: int64

# %%
# Label based selection.
df.loc[0, 'CENSUS2010POP']
# Out:
# 3944153

# %%
df.set_index('CENSUS2010POP')
# Out:
#                SEX  AGE  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# CENSUS2010POP
# 3944153          0    0            3944160          3951330          3963087
# 3978070          0    1            3978090          3957888          3966551
# 4096929          0    2            4096939          4090862          3971565
# 4119040          0    3            4119051          4111920          4102470
# 4063170          0    4            4063186          4077551          4122294
# ...            ...  ...                ...              ...              ...
# 53582            2   97              53605            54118            57159
# 36641            2   98              36675            37532            40116
# 26193            2   99              26214            26074            27030
# 44202            2  100              44246            45058            47556
# 156964212        2  999          156969328        157258820        158427085
#
# ...

# %%
df = pd.read_csv('../data_sets/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Get all people whose BloodPressure is < 50 and BMI is <30.
df[(df.BloodPressure < 50) & (df.BMI < 30)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 49             7      105              0              0        0   0.0
# 60             2       84              0              0        0   0.0
# 75             1        0             48             20        0  24.7
# 80             3      113             44             13        0  22.4
# 81             2       74              0              0        0   0.0
# 97             1       71             48             18       76  20.4
# 172            2       87              0             23        0  28.9
# 222            7      119              0              0        0  25.2
# 269            2      146              0              0        0  27.5
# 346            1      139             46             19       83  28.7
# 347            3      116              0              0        0  23.5
# 426            0       94              0              0        0   0.0
# ...

# %%
# Remap BloodPressure values so that mean is at 0
df.BloodPressure.map(lambda p: p - df.BloodPressure.mean())
# Out:
# 0       2.894531
# 1      -3.105469
# 2      -5.105469
# 3      -3.105469
# 4     -29.105469
#          ...
# 763     6.894531
# 764     0.894531
# 765     2.894531
# 766    -9.105469
# 767     0.894531
# Name: BloodPressure, Length: 768, dtype: float64
